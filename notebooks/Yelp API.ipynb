# %%
import yelpapi
from yelpapi import YelpAPI

consumer_key = "e4g1KDmymkKT4ce6lLLK0g"
consumer_secret = "JnPgMASskUH3OEvkspy42kqt48U"
token = "pGazjSgqT_i96VtLEAIIe_Ye9oeG1ZsL"
token_secret = "B0F4R0J1PzYudmarsPC453fYd08"

yelp_api = YelpAPI(consumer_key, consumer_secret, token, token_secret)
search_results = yelp_api.search_query(term='pho', location='berkeley, ca', sort=2, limit=5, cll='37.8717, 122.2728')
# business_results = yelp_api.business_query(id=business_id, other_args)

# %%
search_results
# Out:
# {u'businesses': [{u'categories': [[u'Vietnamese', u'vietnamese']],
#    u'display_phone': u'+1-510-788-4459',
#    u'id': u'monster-pho-oakland',
#    u'image_url': u'http://s3-media3.ak.yelpcdn.com/bphoto/8iNjXYOMykDOFNY6UEtQ4w/ms.jpg',
#    u'is_claimed': True,
#    u'is_closed': False,
#    u'location': {u'address': [u'3905 Broadway'],
#     u'city': u'Oakland',
#     u'country_code': u'US',
#     u'cross_streets': u'40th St & 40th Street Way',
#     u'display_address': [u'3905 Broadway',
#      u'(b/t 40th St & 40th Street Way)',
#      u'North Oakland',
#      u'Oakland, CA 94611'],
#     u'neighborhoods': [u'North Oakland'],
#     u'postal_code': u'94611',
#     u'state_code': u'CA'},
#    u'mobile_url': u'http://m.yelp.com/biz/monster-pho-oakland',
#    u'name': u'Monster Pho',
#    u'phone': u'5107884459',
#    u'rating': 4.5,
#    u'rating_img_url': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    u'rating_img_url_large': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    u'rating_img_url_small': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    u'review_count': 72,
#    u'snippet_image_url': u'http://s3-media2.ak.yelpcdn.com/photo/brs8zHER3a5cXvh8okjHVQ/ms.jpg',
#    u'snippet_text': u'Monster Pho is phenomenal in every aspect!!\n\nJust coming out of the aftermath of a rave, my group of friends all needed a soup base in their system, and...',
#    u'url': u'http://www.yelp.com/biz/monster-pho-oakland'},
#   {u'categories': [[u'Vietnamese', u'vietnamese']],
#    u'display_phone': u'+1-510-534-2828',
#    u'id': u'b\xfan-mam-s\xf3c-trang-oakland-2',
#    u'image_url': u'http://s3-media1.ak.yelpcdn.com/bphoto/Ip4V6_RtDivzloO-Zj6jSg/ms.jpg',
#    u'is_claimed': True,
#    u'is_closed': False,
#    u'location': {u'address': [u'1326 E 18th St'],
#     u'city': u'Oakland',
#     u'country_code': u'US',
#     u'cross_streets': u'13th Ave & Solano Way',
#     u'display_address': [u'1326 E 18th St',
#      u'(b/t 13th Ave & Solano Way)',
#      u'East Oakland',
#      u'Oakland, CA 94606'],
#     u'neighborhoods': [u'East Oakland'],
#     u'postal_code': u'94606',
#     u'state_code': u'CA'},
#    u'mobile_url': u'http://m.yelp.com/biz/b%C3%BAn-mam-s%C3%B3c-trang-oakland-2',
#    u'name': u'B\xfan Mam S\xf3c Trang',
#    u'phone': u'5105342828',
#    u'rating': 4.5,
#    u'rating_img_url': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    u'rating_img_url_large': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    u'rating_img_url_small': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    u'review_count': 164,
#    u'snippet_image_url': u'http://s3-media4.ak.yelpcdn.com/photo/OrtZ_s76yadL5DFMpThO7Q/ms.jpg',
#    u'snippet_text': u"I came here with a fellow food lover and was warned that the broth alone wasn't going to impress.... that it's the sum of the dish's parts which makes this...",
#    u'url': u'http://www.yelp.com/biz/b%C3%BAn-mam-s%C3%B3c-trang-oakland-2'},
#   {u'categories': [[u'Caterers', u'catering'],
#     [u'Vietnamese', u'vietnamese'],
#     [u'Delis', u'delis']],
#    u'display_phone': u'+1-510-528-8882',
#    u'id': u'banh-mi-ba-le-vietnamese-sandwich-deli-el-cerrito',
#    u'image_url': u'http://s3-media1.ak.yelpcdn.com/bphoto/JI52BXobDVVGSiCppofjCg/ms.jpg',
#    u'is_claimed': False,
#    u'is_closed': False,
#    u'location': {u'address': [u'10174 San Pablo Ave'],
#     u'city': u'El Cerrito',
#     u'country_code': u'US',
#     u'display_address': [u'10174 San Pablo Ave', u'El Cerrito, CA 94530'],
#     u'postal_code': u'94530',
#     u'state_code': u'CA'},
#    u'menu_date_updated': 1387611773,
#    u'menu_provider': u'single_platform',
#    u'mobile_url': u'http://m.yelp.com/biz/banh-mi-ba-le-vietnamese-sandwich-deli-el-cerrito',
#    u'name': u'Banh Mi Ba Le Vietnamese Sandwich Deli',
#    u'phone': u'5105288882',
#    u'rating': 4.0,
#    u'rating_img_url': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    u'rating_img_url_large': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    u'rating_img_url_small': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    u'review_count': 340,
#    u'snippet_image_url': u'http://s3-media1.ak.yelpcdn.com/photo/xqrR1xAhomkLYD8U-KEJpA/ms.jpg',
#    u'snippet_text': u'Best damn $3 sandwich anywhere!\nBest damn bahn mi anywhere, period!\nExtremely friendly service, too - my car died in the parking lot & the feller even came...',
#    u'url': u'http://www.yelp.com/biz/banh-mi-ba-le-vietnamese-sandwich-deli-el-cerrito'},
#   {u'categories': [[u'Vietnamese', u'vietnamese']],
#    u'display_phone': u'+1-510-836-3139',
#    u'id': u'kim-huong-oakland',
#    u'image_url': u'http://s3-media1.ak.yelpcdn.com/bphoto/DOfeCEoAR9VzDeBadGhZEA/ms.jpg',
#    u'is_claimed': False,
#    u'is_closed': False,
#    u'location': {u'address': [u'304 10th St'],
#     u'city': u'Oakland',
#     u'country_code': u'US',
#     u'cross_streets': u'Webster St & Harrison St',
#     u'display_address': [u'304 10th St',
#      u'(b/t Webster St & Harrison St)',
#      u'Oakland Chinatown',
#      u'Oakland, CA 94607'],
#     u'neighborhoods': [u'Oakland Chinatown'],
#     u'postal_code': u'94607',
#     u'state_code': u'CA'},
#    u'menu_date_updated': 1387633870,
#    u'menu_provider': u'single_platform',
#    u'mobile_url': u'http://m.yelp.com/biz/kim-huong-oakland',
#    u'name': u'Kim Huong',
#    u'phone': u'5108363139',
#    u'rating': 4.0,
#    u'rating_img_url': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    u'rating_img_url_large': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    u'rating_img_url_small': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    u'review_count': 186,
#    u'snippet_image_url': u'http://s3-media3.ak.yelpcdn.com/photo/F6LS4oLfCh5hlZPzLC-szA/ms.jpg',
#    u'snippet_text': u'The pho was delicious and the super nice owner recommended another soup that was also very tasty. \n\nThe restaurant was clean. They had the nature channel on...',
#    u'url': u'http://www.yelp.com/biz/kim-huong-oakland'},
#   {u'categories': [[u'Vietnamese', u'vietnamese']],
#    u'display_phone': u'+1-510-835-8488',
#    u'id': u'pho-ga-huong-que-cafe-oakland',
#    u'image_url': u'http://s3-media4.ak.yelpcdn.com/bphoto/BvvwmiXMMMaedLCsLoXIJg/ms.jpg',
#    u'is_claimed': False,
#    u'is_closed': False,
#    u'location': {u'address': [u'1228 7th Ave'],
#     u'city': u'Oakland',
#     u'country_code': u'US',
#     u'cross_streets': u'12th St & 14th St',
#     u'display_address': [u'1228 7th Ave',
#      u'(b/t 12th St & 14th St)',
#      u'East Oakland',
#      u'Oakland, CA 94606'],
#     u'neighborhoods': [u'East Oakland'],
#     u'postal_code': u'94606',
#     u'state_code': u'CA'},
#    u'mobile_url': u'http://m.yelp.com/biz/pho-ga-huong-que-cafe-oakland',
#    u'name': u'Pho Ga Huong Que Cafe',
#    u'phone': u'5108358488',
#    u'rating': 4.0,
#    u'rating_img_url': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    u'rating_img_url_large': u'http://s3-media2.ak.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    u'rating_img_url_small': u'http://s3-media4.ak.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    u'review_count': 225,
#    u'snippet_image_url': u'http://s3-media3.ak.yelpcdn.com/photo/xfefoN1y7RoCCcPv0UFkvw/ms.jpg',
#    u'snippet_text': u'My favorite pho ga spot!\n\nFor $6, you get a bowl of noodles which includes thick/thin rice noodles and boneless/bone-in white or dark meat chicken slices....',
#    u'url': u'http://www.yelp.com/biz/pho-ga-huong-que-cafe-oakland'}],
#  u'region': {u'center': {u'latitude': 37.84793555,
#    u'longitude': -122.27352619999999},
#   u'span': {u'latitude_delta': 0.12263976999999215,
#    u'longitude_delta': 0.06690112000001136}},
#  u'total': 40}
