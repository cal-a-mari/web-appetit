# %%
import yelpapi
from yelpapi import YelpAPI

consumer_key = "e4g1KDmymkKT4ce6lLLK0g"
consumer_secret = "JnPgMASskUH3OEvkspy42kqt48U"
token = "pGazjSgqT_i96VtLEAIIe_Ye9oeG1ZsL"
token_secret = "B0F4R0J1PzYudmarsPC453fYd08"

yelp_api = YelpAPI(consumer_key, consumer_secret, token, token_secret)
search_results = yelp_api.search_query(term='pho', location='san francisco, ca', sort=2, limit=5)
# business_results = yelp_api.business_query(id=business_id, other_args)

# %%
search_results
# Out:
# {u'businesses': [{u'categories': [[u'Vietnamese', u'vietnamese']],
#    u'display_phone': u'+1-415-674-4146',
#    u'id': u'four-seasons-restaurant-san-francisco-2',
#    u'image_url': u'http://s3-media3.ak.yelpcdn.com/bphoto/BVl5cEACDUfVS_KJBkiGqw/ms.jpg',
#    u'is_claimed': True,
#    u'is_closed': False,
#    u'location': {u'address': [u'721 Larkin St'],
#     u'city': u'San Francisco',
#     u'country_code': u'US',
#     u'cross_streets': u'Olive St & Ellis St',
#     u'display_address': [u'721 Larkin St',
#      u'(b/t Olive St & Ellis St)',
#      u'Tenderloin',
#      u'San Francisco, CA 94109'],
#     u'neighborhoods': [u'Tenderloin'],
#     u'postal_code': u'94109',
#     u'state_code': u'CA'},
#    u'mobile_url': u'http://m.yelp.com/biz/four-seasons-restaurant-san-francisco-2',
#    u'name': u'Four Seasons Restaurant',
#    u'phone': u'4156744146',
#    u'rating': 4.5,
# ...
