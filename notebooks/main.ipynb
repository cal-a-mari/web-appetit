# %%
"""
This notebook includes all the main functions we created to parse Flickr photo data
"""

# %%
import flickrapi
from flickrapi import shorturl
from IPython.display import display, Image
import json

APIKEY = "800f28ae42a58a95f0005fb0fe022a78"

flickr = flickrapi.FlickrAPI(APIKEY)

# %%
from IPython.display import HTML
from jinja2 import Template

CSS = """
<style>
  .wrap img {
    margin-left: 0px;
    margin-right: 0px;
    display: inline-block;
    width: 150px;
  }
  
.wrap {
   /* Prevent vertical gaps */
   line-height: 0;
   
   -webkit-column-count: 5;
   -webkit-column-gap:   0px;
   -moz-column-count:    5;
   -moz-column-gap:      0px;
   column-count:         5;
   column-gap:           0px;
   
}
.wrap img {
  /* Just in case there are inline attributes */
  width: 100% !important;
  height: auto !important;
}

</style>
"""

IMAGES_TEMPLATE = CSS + """
<div class="wrap">
 {% for item in items %}<img src="{{item}}"/>{% endfor %}
</div>
"""

template = Template(IMAGES_TEMPLATE)

# To display photos in HTML, use:

# photos = get_photos_static_urls(flickr.photos_search(
#     tag_mode='any',
#     text='uc berkeley',
#     format='json'))

#   template = Template(IMAGES_TEMPLATE)
#   HTML(template.render(items=photos[:30]))  # shows first 30 photos

# %%
"""
Given a flickr api search query with format='json', returns the data in actual json format

get_json(flickr.photos_search(
        tag_mode='any',
        tag='dog',
        license='7',
        format='json'))
"""
def get_json(flickr_search_response):
    json_string = flickr_search_response[14:-1]
    return json.loads(json_string)

"""
Returns the json data including pages, total photo count, and list of photos
"""
def get_data(flickr_search_response):
    return get_json(flickr_search_response)['photos']

"""
Returns the json list of photos

u'photo': [{u'farm': 6,
   u'id': u'11292885426',
   u'isfamily': 0,
   u'isfriend': 0,
   u'ispublic': 1,
   u'owner': u'12403504@N02',
   u'secret': u'f09443f484',
   u'server': u'5538',
   u'title': u"Image taken from page 392 of 'Northward over the \u201cGreat Ice\u201d: a 
    narrative of life and work along the shores and upon the interior ice-cap of Northern 
    Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations'"},
"""
def get_photos(flickr_search_response):
    return get_json(flickr_search_response)['photos']['photo']

"""
Returns array of Flikr photo URLs -- opens in Flickr photo viewer
"""
def get_photo_urls(flickr_search_response):
    photo_list = get_photos(flickr_search_response)
    photo_urls = []
    for photo in photo_list:
        photo_urls.append(flickrapi.shorturl.url(photo['id']))
    return photo_urls

"""
Returns array of direct photo jpg URLs
"""
def get_photos_static_urls(flickr_search_response):
    photo_list = get_photos(flickr_search_response)
    photo_urls = []
    for photo in photo_list:
        # http://farm{farm-id}.staticflickr.com/{server-id}/{id}_{o-secret}_o.(jpg|gif|png)
        # http://farm1.staticflickr.com/2/1418878_1e92283336_m.jpg
        size = "m" # m, z, b
        # for list of sizes see https://www.flickr.com/services/api/misc.urls.html
        url = "http://farm" + str(photo['farm']) + ".staticflickr.com/" + photo['server'] + "/" + photo['id'] + "_" + photo['secret'] +  "_" + size + ".jpg"   
        photo_urls.append(url)
    return photo_urls

"""
Returns the count of results
"""
def get_count(flickr_search_response):
    return get_json(flickr_search_response)['photos']['total']

# %%
"""
Search Parameters 

extras

A comma-delimited list of extra information to fetch for each returned record. 
Currently supported fields are: 

description, license, date_upload, date_taken, owner_name, icon_server, 
original_format, last_update, geo, tags, machine_tags, o_dims, views, 
media, path_alias, url_sq, url_t, url_s, url_q, url_m, url_n, url_z, url_c, url_l, url_o
"""

# %%
"""
Examples of how to use function calls:
"""

# %%
get_count(flickr.photos_search(
        tag_mode='any',
        tag='dog',
        license='7',
        format='json'))
# Out:
# u'858218'

# %%
get_photos(flickr.photos_search(
        text='dog',
        extras='license, date_upload, last_update, date_taken, owner_name, geo, tags, views, url_m',
        license='7',
        format='json'))
# Out:
# [{u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-09 17:13:02',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397812050',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Northward over the \u201cGreat Ice\u201d: a narrative of life and work along the shores and upon the interior ice-cap of Northern Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations&quot;\n<strong>Author</strong>: PEARY, Robert Edwin.\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 10460.dd.20.&quot;\n<strong>Volume</strong>: 02\n<strong>Page</strong>: 392\n<strong>Place of Publishing</strong>: London; printed in America\n<strong>Date of Publishing</strong>: 1898\n<strong>Publisher</strong>: Methuen &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 002805945\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01002805945&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=002805945&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum002805945">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1898">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 6,
#   u'height_m': u'167',
#   u'id': u'11292885426',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1398157503',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'f09443f484',
#   u'server': u'5538',
#   u'tags': u'dog team medium sled rotated publicdomain vol02 page392 bldigital vision:text=0635 vision:outdoor=0847 pubplacelondonprintedinamerica date1898 sysnum002805945 pearyrobertedwin',
#   u'title': u"Image taken from page 392 of 'Northward over the \u201cGreat Ice\u201d: a narrative of life and work along the shores and upon the interior ice-cap of Northern Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations'",
#   u'url_m': u'http://farm6.staticflickr.com/5538/11292885426_f09443f484.jpg',
#   u'views': u'2261',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'1915-01-01 00:00:00',
#   u'datetakengranularity': u'8',
#   u'dateupload': u'1397226106',
#   u'description': {u'_content': u'Bain News Service,, publisher.\n\nGerman Red Cross Dogs going to front\n\n[between ca. 1915 and ca. 1920]\n\n1 negative : glass ; 5 x 7 in. or smaller.\n\n<b>Notes:\n</b> Title from unverified data provided by the Bain News Service on the negatives or caption cards.\nForms part of: George Grantham Bain Collection (Library of Congress).\n\n<b>Format: </b> Glass negatives.\n\n<b>Rights Info: </b> No known restrictions on publication.\n\n<b>Repository: </b> Library of Congress, Prints and Photographs Division, Washington, D.C. 20540 USA, <a href="http://hdl.loc.gov/loc.pnp/pp.print" rel="nofollow">hdl.loc.gov/loc.pnp/pp.print</a>\n\nGeneral information about the Bain Collection is available at <a href="http://hdl.loc.gov/loc.pnp/pp.ggbain" rel="nofollow">hdl.loc.gov/loc.pnp/pp.ggbain</a>\n\n<b>Higher resolution image is available (Persistent URL): </b> <a href="http://hdl.loc.gov/loc.pnp/ggbain.22086" rel="nofollow">hdl.loc.gov/loc.pnp/ggbain.22086</a>\n\n<b>Call Number: </b> LC-B2- 3897-4\n\n'},
#   u'farm': 3,
#   u'height_m': u'363',
#   u'id': u'13779194673',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397802579',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'8623220@N02',
#   u'ownername': u'The Library of Congress',
#   u'secret': u'2d7d694e97',
#   u'server': u'2902',
#   u'tags': u'libraryofcongress xmlns:dc=httppurlorgdcelements11 dc:identifier=httphdllocgovlocpnpggbain22086',
#   u'title': u'German Red Cross Dogs going to front (LOC)',
#   u'url_m': u'http://farm3.staticflickr.com/2902/13779194673_2d7d694e97.jpg',
#   u'views': u'4061',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-06 17:26:34',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397207324',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Voyage et aventures autour du monde de Robert Kergorie\u0300u. [With plates.]&quot;\n<strong>Author</strong>: AUDEBRAND, Philibert.\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 10027.h.22.&quot;\n<strong>Page</strong>: 346\n<strong>Place of Publishing</strong>: Paris\n<strong>Date of Publishing</strong>: 1862\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 000139446\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01000139446&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=000139446&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum000139446">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1862">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 4,
#   u'height_m': u'386',
#   u'id': u'11239342056',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397363003',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'0f6756fee1',
#   u'server': u'3719',
#   u'tags': u'medium publicdomain sleddogs vol0 vision:mountain=065 bldigital vision:text=0544 pubplaceparis mechanicalcurator date1862 vision:outdoor=0964 vision:car=0506 page346 sysnum000139446 audebrandphilibert imagesfrombook000139446 imagesfromvolume0001394460',
#   u'title': u"Image taken from page 346 of 'Voyage et aventures autour du monde de Robert Kergorie\u0300u. [With plates.]'",
#   u'url_m': u'http://farm4.staticflickr.com/3719/11239342056_0f6756fee1.jpg',
#   u'views': u'6357',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-04-02 10:51:59',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397054456',
#   u'description': {u'_content': u"Overhills, Harnett County, NC, Manchester vicinity, 1920s-1930's.  From the General Negative Collection, State Archives of North Carolina."},
#   u'farm': 3,
#   u'height_m': u'301',
#   u'id': u'13739122703',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397118778',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'24231108@N08',
#   u'ownername': u'State Archives of North Carolina',
#   u'secret': u'500b955113',
#   u'server': u'2895',
#   u'tags': u'dogs',
#   u'title': u'N_92_1_374',
#   u'url_m': u'http://farm3.staticflickr.com/2895/13739122703_500b955113.jpg',
#   u'views': u'175',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-04-02 10:51:14',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397054457',
#   u'description': {u'_content': u"Overhills, Harnett County, NC, Manchester vicinity, 1920s-1930's.  From the General Negative Collection, State Archives of North Carolina."},
#   u'farm': 8,
#   u'height_m': u'302',
#   u'id': u'13739078745',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397103832',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'24231108@N08',
#   u'ownername': u'State Archives of North Carolina',
#   u'secret': u'd6ed8778be',
#   u'server': u'7453',
#   u'tags': u'dogs',
#   u'title': u'N_92_1_375',
#   u'url_m': u'http://farm8.staticflickr.com/7453/13739078745_d6ed8778be.jpg',
#   u'views': u'170',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-04-02 12:35:14',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397054423',
#   u'description': {u'_content': u"Overhills, Harnett County, NC, Manchester vicinity, 1910s-1920's.  From the General Negative Collection, State Archives of North Carolina. "},
#   u'farm': 8,
#   u'height_m': u'301',
#   u'id': u'13739127853',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397151980',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'24231108@N08',
#   u'ownername': u'State Archives of North Carolina',
#   u'secret': u'5edd7ec863',
#   u'server': u'7225',
#   u'tags': u'dogs hunting',
#   u'title': u'N_92_1_317',
#   u'url_m': u'http://farm8.staticflickr.com/7225/13739127853_5edd7ec863.jpg',
#   u'views': u'142',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-03-26 13:33:00',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397054360',
#   u'description': {u'_content': u'Overhills, Harnett County, NC, Manchester vicinity, 1920s.  From the General Negative Collection, State Archives of North Carolina.'},
#   u'farm': 3,
#   u'height_m': u'309',
#   u'id': u'13739084183',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397055898',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'24231108@N08',
#   u'ownername': u'State Archives of North Carolina',
#   u'secret': u'649bc64d91',
#   u'server': u'2902',
#   u'tags': u'dogs hunting',
#   u'title': u'N_92_1_286',
#   u'url_m': u'http://farm3.staticflickr.com/2902/13739084183_649bc64d91.jpg',
#   u'views': u'70',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-03-26 13:31:24',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397054360',
#   u'description': {u'_content': u'Overhills, Harnett County, NC, Manchester vicinity, 1920s.  From the General Negative Collection, State Archives of North Carolina.'},
#   u'farm': 8,
#   u'height_m': u'500',
#   u'id': u'13739443014',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397055898',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'24231108@N08',
#   u'ownername': u'State Archives of North Carolina',
#   u'secret': u'6da02408b1',
#   u'server': u'7214',
#   u'tags': u'dogs hunting',
#   u'title': u'N_92_1_287',
#   u'url_m': u'http://farm8.staticflickr.com/7214/13739443014_6da02408b1.jpg',
#   u'views': u'73',
#   u'width_m': u'304'},
#  {u'accuracy': u'13',
#   u'context': 0,
#   u'datetaken': u'2008-11-28 10:27:02',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1396931260',
#   u'description': {u'_content': u'Find more detailed information about this photograph: <a href="http://acmssearch.sl.nsw.gov.au/search/itemDetailPaged.cgi?itemID=413771" rel="nofollow">acmssearch.sl.nsw.gov.au/search/itemDetailPaged.cgi?itemI...</a>\nSearch for more great images in the State Library\'s collections: <a href="http://acms.sl.nsw.gov.au/search/SimpleSearch.aspx" rel="nofollow">acms.sl.nsw.gov.au/search/SimpleSearch.aspx</a>\n\n\nFrom the collection of the State Library of New South Wales: <a href="http://www.sl.nsw.gov.au" rel="nofollow">www.sl.nsw.gov.au</a>'},
#   u'farm': 8,
#   u'geo_is_contact': 0,
#   u'geo_is_family': 0,
#   u'geo_is_friend': 0,
#   u'geo_is_public': 1,
#   u'height_m': u'347',
#   u'id': u'13708316534',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397780074',
#   u'latitude': -33.86621,
#   u'license': u'7',
#   u'longitude': 151.217236,
#   u'owner': u'29454428@N08',
#   u'ownername': u'State Library of New South Wales collection',
#   u'place_id': u'2AEwArxQU7pLPY08',
#   u'secret': u'96b8dcd521',
#   u'server': u'7060',
#   u'tags': u'',
#   u'title': u'Botanical Gardens, Sydney, [showing Hunstman and Dogs sculpture] c. 1900-1910',
#   u'url_m': u'http://farm8.staticflickr.com/7060/13708316534_96b8dcd521.jpg',
#   u'views': u'839',
#   u'width_m': u'500',
#   u'woeid': u'1105779'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-04-04 13:21:49',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1396642909',
#   u'description': {u'_content': u'Images from an Album (AL-247) donated to SDASM by Jane Forsyth showing Edwards Air Force Base in the 1950s.  \n\nRepository: <a href="http://www.sandiegoairandspace.org/library/stillimages.html" rel="nofollow">San Diego Air and Space Museum Archive</a>'},
#   u'farm': 3,
#   u'height_m': u'500',
#   u'id': u'13630141093',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397176963',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'49487266@N07',
#   u'ownername': u'San Diego Air & Space Museum Archives',
#   u'secret': u'04a7dc8c9d',
#   u'server': u'2832',
#   u'tags': u'russell aviation edwardsafb f80 murray aviator yeager x5 b36 ridley arthurmurray edwardsairforcebase t28 chuckyeager f89 f84 testpilot f86d p80 b45 b36peacemaker northropf89scorpion t28trojan f89scorpion northamericant28trojan bellx5 sabredog testpilots convairf102 ascani xf92 convairb36peacemaker northamericanb45tornado lockheedp80 lockheedp80shootingstar republicf84 republicf84thunderjet convairb36 northamericanb45 jackridley convairxf92 kitmurray northamericanf86dsabredog bellb1 arthurwkitmurray arthurwmurray holtoner',
#   u'title': u'AL247-016',
#   u'url_m': u'http://farm3.staticflickr.com/2832/13630141093_04a7dc8c9d.jpg',
#   u'views': u'575',
#   u'width_m': u'407'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-03-27 16:06:35',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1395950887',
#   u'description': {u'_content': u'b&amp;w print. Charles B. Spalding with Lady, girl - Gardinea Thompson and dog on hood.  Taken in a driveway.\nBack:  taken at Burlington Beach, 1904.  The car is a 1903 Rambler made by the Jefferies Manu. Co. Kenooks (?) Wisconsin.  Owned and driven by Charles B. Spalding.  The small child is Garninea Thompson.'},
#   u'farm': 8,
#   u'height_m': u'282',
#   u'id': u'13453086375',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1395951843',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'39758725@N03',
#   u'ownername': u'Dundas Museum and Archives',
#   u'secret': u'34f699868a',
#   u'server': u'7065',
#   u'tags': u'',
#   u'title': u'Automobiles',
#   u'url_m': u'http://farm8.staticflickr.com/7065/13453086375_34f699868a.jpg',
#   u'views': u'225',
#   u'width_m': u'448'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'1900-01-01 00:00:00',
#   u'datetakengranularity': u'8',
#   u'dateupload': u'1395417656',
#   u'description': {u'_content': u'Left to right: Alan, Robert Jr., Emily, unknown, Mary (and a dog).  ca. 1900.  From the Robert Brebner fonds, PR2009.0499/128.'},
#   u'farm': 8,
#   u'height_m': u'386',
#   u'id': u'13310441234',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1395421185',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'95711690@N03',
#   u'ownername': u'Provincial Archives of Alberta',
#   u'secret': u'f50fe2c70f',
#   u'server': u'7077',
#   u'tags': u'portraits alberta homesteads sprucegrove vision:people=099 vision:face=099 vision:groupshot=099 vision:outdoor=0844',
#   u'title': u'Brebner family',
#   u'url_m': u'http://farm8.staticflickr.com/7077/13310441234_f50fe2c70f.jpg',
#   u'views': u'641',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-05 15:46:33',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1395392517',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Always in the Way; ... With ... illustrations, etc. (New edition.)&quot;\n<strong>Author</strong>: JEANS, Thomas - Novelist\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 012621.e.8.&quot;\n<strong>Page</strong>: 72\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1893\n<strong>Publisher</strong>: A. P. Marsden\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 001858318\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01001858318&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=001858318&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum001858318">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1893">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 8,
#   u'height_m': u'320',
#   u'id': u'11222803106',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1395709225',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'0963978e49',
#   u'server': u'7373',
#   u'tags': u'dog man gun large rotated publicdomain page72 poacher trespasser vol0 bldigital vision:text=0748 mechanicalcurator pubplacelondon date1893 vision:outdoor=0915 jeansthomasnovelist sysnum001858318 imagesfrombook001858318 imagesfromvolume0018583180 mrrummins',
#   u'title': u"Image taken from page 72 of 'Always in the Way; ... With ... illustrations, etc. (New edition.)'",
#   u'url_m': u'http://farm8.staticflickr.com/7373/11222803106_0963978e49.jpg',
#   u'views': u'4312',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-11-26 06:42:51',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1395392858',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Charley Wag, the new Jack Sheppard. A new and intensely exciting real-life romance&quot;\n<strong>Author</strong>: WAG, Charley.\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12625.g.35.&quot;\n<strong>Page</strong>: 213\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1861\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003826797\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003826797&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003826797&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003826797">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1861">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 6,
#   u'height_m': u'500',
#   u'id': u'11062816216',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1395541420',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'7f41ab7c0e',
#   u'server': u'5483',
#   u'tags': u'horse dog large publicdomain vol0 page213 bldigital vision:text=06 mechanicalcurator pubplacelondon date1861 vision:outdoor=0959 sysnum003826797 wagcharley imagesfrombook003826797 imagesfromvolume0038267970',
#   u'title': u"Image taken from page 213 of 'Charley Wag, the new Jack Sheppard. A new and intensely exciting real-life romance'",
#   u'url_m': u'http://farm6.staticflickr.com/5483/11062816216_7f41ab7c0e.jpg',
#   u'views': u'7360',
#   u'width_m': u'388'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-03-17 08:39:25',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1395045596',
#   u'description': {u'_content': u'<b>Teitl Cymraeg/Welsh title:</b> Cymwynasgarwch ar fynyddoedd Cymru, hel defaid Glan Meryn, Machynlleth\n<b>Ffotograffydd/Photographer:</b> Geoff Charles (1909-2002)\n<b>Dyddiad/Date:</b> 11/6/1954\n<b>Cyfrwng/Medium:</b>  Negydd ffilm / Film negative\n<b>Cyfeiriad/Reference:</b> (gch12728)\n<b>Rhif cofnod / Record no.:</b>  <a href="http://cat.llgc.org.uk/cgi-bin/gw/chameleon?skin=eresources&amp;lng=en&amp;inst=consortium&amp;conf=./chameleon.conf&amp;search=KEYWORD&amp;function=INITREQ&amp;elementcount=1&amp;u1=12101&amp;op1=0&amp;t1= 3367762" rel="nofollow">3367762</a>\n\n<i><a href="http://www.llgc.org.uk/index.php?id=345&amp;L=1" rel="nofollow">Rhagor o wybodaeth</a> am gasgliad Geoff Charles yn Llyfrgell Genedlaethol Cymru</i>\n\n<i><a href="http://www.llgc.org.uk/index.php?id=geoffcharles" rel="nofollow">More information</a> about the Geoff Charles Collection at the National Library of Wales</i>\n\n<i> Mae ffotograffau Geoff Charles hefyd yn rhan o <a href="http://www.llgc.org.uk/index.php?id=5728&amp;L=1" rel="nofollow">Broject Europeana Libraries</a></i>\n\n<i>Geoff Charles\' photographs also form part of the <a href="http://www.llgc.org.uk/index.php?id=5728" rel="nofollow">Europeana Libraries Project</a></i>'},
#   u'farm': 4,
#   u'height_m': u'383',
#   u'id': u'13214078914',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1397654914',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'37199428@N06',
#   u'ownername': u'LlGC ~ NLW',
#   u'secret': u'a595a207d8',
#   u'server': u'3770',
#   u'tags': u'horses mountains wales farmers farming cymru tractors machynlleth workingdogs llyfrgellgenedlaetholcymru nationallibraryofwales groupportraits plynlimon filmnegatives charlesgeoff19092002 negyddffilm vision:mountain=0736 vision:outdoor=0989',
#   u'title': u"Farmers helping each other to round up Glan Meryn's sheep, Machynlleth",
#   u'url_m': u'http://farm4.staticflickr.com/3770/13214078914_a595a207d8.jpg',
#   u'views': u'900',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'1937-01-01 00:00:00',
#   u'datetakengranularity': u'8',
#   u'dateupload': u'1394672664',
#   u'description': {u'_content': u'<strong>Title:</strong> Thomas William Turner Motion Pictures\n\n<strong>Creator:</strong> Thomas William Turner\n\n<strong>Location:</strong> Hamilton, Brisbane, Queensland\n\n<strong>Description:</strong> Home movie of capture of shark believed to have been caught in the Brisbane river 1937-1938. Group gathered around hanging shark, Kingsford Smith Drive, Hamilton. Footage of a small pet dog and boy.\n\n<strong>Reference code:</strong> 4686\n\n<strong>More about this collection at the State Library of Queensland:</strong> <a href="http://hdl.handle.net/10462/eadarc/6596" rel="nofollow">hdl.handle.net/10462/eadarc/6596</a>'},
#   u'farm': 8,
#   u'height_m': u'400',
#   u'id': u'13116456285',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1394766676',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'32605636@N06',
#   u'ownername': u'State Library of Queensland, Australia',
#   u'secret': u'00c54146e1',
#   u'server': u'7328',
#   u'tags': u'river shark boat fishing brisbaneriver',
#   u'title': u'Shark caught in Brisbane River at Hamilton, Brisbane, circa 1937.',
#   u'url_m': u'http://farm8.staticflickr.com/7328/13116456285_00c54146e1.jpg',
#   u'views': u'1076',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2011-10-12 13:54:24',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1393934537',
#   u'description': {u'_content': u'<b>Subject</b>: Ballinger, Wynne Sharples 1923-2008\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Radcliffe College\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Columbia University College of Physicians and Surgeons\n\n<b>Type</b>: Black-and-white photographs\n\n<b>Topic</b>: Medicine\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Women scientists\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Cystic fibrosis\n\n<b>Local number</b>: SIA Acc. 90-105 [SIA2009-3246]\n\n<b>Summary</b>: As a pediatrician and mother, Wynne Sharples (Ballinger) (1923-2008) became known for her advocacy work on cystic fibrosis. In 1945, she was working in the biological laboratories at Radcliffe College and then trained at Columbia University\'s College of Physicians and Surgeons in New York. She founded the Cystic Fibrosis Research Institute of Pennsylvania in 1960, after two of her children were diagnosed with the disease. Later in her life, she lived in Palm Beach, Florida, where she founded the Horticulture Society of South Florida and was an award-winning breeder of Pekingese dogs, which she had been showing since the 1970s\n\n<b>Cite as</b>: Acc. 90-105 - Science Service, Records, 1920s-1970s, Smithsonian Institution Archives\n\n<b>Persistent URL</b>:<a href="http://siris-archives.si.edu/ipac20/ipac.jsp?&amp;profile=all&amp;source=~!siarchives&amp;uri=full=3100001~!306467~!0#focus" rel="nofollow">Link to data base record</a>\n\n<b>Repository</b>:<a href="http://siarchives.si.edu" rel="nofollow">Smithsonian Institution Archives</a>\n\n<a href="http://collections.si.edu/search/results.htm?q=&amp;fq=object_type:Photographs&amp;fq=online_media_type:Images&amp;view=grid&amp;repo=flickr" rel="nofollow"><b>View more collections from the Smithsonian Institution.</b></a>'},
#   u'farm': 6,
#   u'height_m': u'500',
#   u'id': u'12484377143',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1393934698',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'25053835@N03',
#   u'ownername': u'Smithsonian Institution',
#   u'secret': u'6a56d9343f',
#   u'server': u'5527',
#   u'tags': u'2014 smithsonianinstitution womenshistorymonth womeninscience smithsonianinstitutionarchives vision:people=099 vision:face=099 vision:outdoor=083 20140301',
#   u'title': u'Wynne Sharples Ballinger (1923-2008)',
#   u'url_m': u'http://farm6.staticflickr.com/5527/12484377143_6a56d9343f.jpg',
#   u'views': u'2337',
#   u'width_m': u'407'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'1915-01-01 00:00:00',
#   u'datetakengranularity': u'8',
#   u'dateupload': u'1393602264',
#   u'description': {u'_content': u'Bain News Service,, publisher.\n\nRed Cross Dog, Gov.\'s Isl.\n\n[between ca. 1915 and ca. 1920]\n\n1 negative : glass ; 5 x 7 in. or smaller.\n\n<b>Notes:\n</b> Title from unverified data provided by the Bain News Service on the negatives or caption cards.\nCorresponding print in LOT 10842 is cropped version of negative.\nForms part of: George Grantham Bain Collection (Library of Congress).\n\n<b>Format: </b> Glass negatives.\n\n<b>Rights Info: </b> No known restrictions on publication.\n\n<b>Repository: </b> Library of Congress, Prints and Photographs Division, Washington, D.C. 20540 USA, <a href="http://hdl.loc.gov/loc.pnp/pp.print" rel="nofollow">hdl.loc.gov/loc.pnp/pp.print</a>\n\nGeneral information about the Bain Collection is available at <a href="http://hdl.loc.gov/loc.pnp/pp.ggbain" rel="nofollow">hdl.loc.gov/loc.pnp/pp.ggbain</a>\n\n<b>Higher resolution image is available (Persistent URL): </b> <a href="http://hdl.loc.gov/loc.pnp/ggbain.21791" rel="nofollow">hdl.loc.gov/loc.pnp/ggbain.21791</a>\n\n<b>Call Number: </b> LC-B2- 3862-14\n\n'},
#   u'farm': 3,
#   u'height_m': u'345',
#   u'id': u'12836225855',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1396013399',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'8623220@N02',
#   u'ownername': u'The Library of Congress',
#   u'secret': u'e6341c0fca',
#   u'server': u'2810',
#   u'tags': u'libraryofcongress xmlns:dc=httppurlorgdcelements11 vision:mountain=0608 vision:clouds=0521 vision:outdoor=0934 vision:sky=058 dc:identifier=httphdllocgovlocpnpggbain21791',
#   u'title': u"Red Cross Dog, Gov.'s Isl. (LOC)",
#   u'url_m': u'http://farm3.staticflickr.com/2810/12836225855_e6341c0fca.jpg',
#   u'views': u'3608',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'1915-01-01 00:00:00',
#   u'datetakengranularity': u'8',
#   u'dateupload': u'1393602286',
#   u'description': {u'_content': u'Bain News Service,, publisher.\n\nRed Cross Dog, Gov.\'s Isl.\n\n[between ca. 1915 and ca. 1920]\n\n1 negative : glass ; 5 x 7 in. or smaller.\n\n<b>Notes:\n</b> Title from unverified data provided by the Bain News Service on the negatives or caption cards.\nForms part of: George Grantham Bain Collection (Library of Congress).\n\n<b>Format: </b> Glass negatives.\n\n<b>Rights Info: </b> No known restrictions on publication.\n\n<b>Repository: </b> Library of Congress, Prints and Photographs Division, Washington, D.C. 20540 USA, <a href="http://hdl.loc.gov/loc.pnp/pp.print" rel="nofollow">hdl.loc.gov/loc.pnp/pp.print</a>\n\nGeneral information about the Bain Collection is available at <a href="http://hdl.loc.gov/loc.pnp/pp.ggbain" rel="nofollow">hdl.loc.gov/loc.pnp/pp.ggbain</a>\n\n<b>Higher resolution image is available (Persistent URL): </b> <a href="http://hdl.loc.gov/loc.pnp/ggbain.21794" rel="nofollow">hdl.loc.gov/loc.pnp/ggbain.21794</a>\n\n<b>Call Number: </b> LC-B2- 3863-3\n\n'},
#   u'farm': 3,
#   u'height_m': u'500',
#   u'id': u'12836314013',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1393950454',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'8623220@N02',
#   u'ownername': u'The Library of Congress',
#   u'secret': u'14504fc3b3',
#   u'server': u'2836',
#   u'tags': u'libraryofcongress xmlns:dc=httppurlorgdcelements11 vision:outdoor=099 dc:identifier=httphdllocgovlocpnpggbain21794',
#   u'title': u"Red Cross Dog, Gov.'s Isl. (LOC)",
#   u'url_m': u'http://farm3.staticflickr.com/2836/12836314013_14504fc3b3.jpg',
#   u'views': u'3566',
#   u'width_m': u'339'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-11-23 09:48:20',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1393578405',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;[The Castles and Abbeys of England ... Illustrated by ... engravings.]&quot;\n<strong>Author</strong>: BEATTIE, William - M.D\n<strong>Contributor</strong>: ALLOM, Thomas.\n<strong>Contributor</strong>: ARCHER, John Wykeham.\n<strong>Contributor</strong>: Bartlett, W. H. (William Henry)\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 10348.i.3.&quot;\n<strong>Volume</strong>: 02\n<strong>Page</strong>: 2\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1844\n<strong>Publisher</strong>: George Virtue\n<strong>Edition</strong>: [Another edition.]\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 000240049\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01000240049&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=000240049&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum000240049">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1844">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 6,
#   u'height_m': u'500',
#   u'id': u'11007099313',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1396290024',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'32784f940a',
#   u'server': u'5495',
#   u'tags': u'dog bird wildlife small peacock page2 publicdomain vol02 bldigital vision:text=0758 mechanicalcurator pubplacelondon date1844 beattiewilliammd sysnum000240049 imagesfromvolume00024004902 imagesfrombook000240049',
#   u'title': u"Image taken from page 2 of '[The Castles and Abbeys of England ... Illustrated by ... engravings.]'",
#   u'url_m': u'http://farm6.staticflickr.com/5495/11007099313_32784f940a.jpg',
#   u'views': u'9452',
#   u'width_m': u'334'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-05 15:53:06',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1393577966',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;A Dog of Flanders and other stories. By Ouida. A new edition, etc&quot;\n<strong>Author</strong>: Ouida\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 012618.h.42.&quot;\n<strong>Page</strong>: 243\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1893\n<strong>Publisher</strong>: Chatto &amp; Windus\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 002732287\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01002732287&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=002732287&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum002732287">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1893">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 6,
#   u'height_m': u'500',
#   u'id': u'11222889566',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1393577966',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'cbfdefd1bc',
#   u'server': u'5484',
#   u'tags': u'large publicdomain ouida page243 vol0 bldigital vision:text=0616 mechanicalcurator pubplacelondon date1893 vision:outdoor=0935 sysnum002732287 imagesfrombook002732287 imagesfromvolume0027322870',
#   u'title': u"Image taken from page 243 of 'A Dog of Flanders and other stories. By Ouida. A new edition, etc'",
#   u'url_m': u'http://farm6.staticflickr.com/5484/11222889566_cbfdefd1bc.jpg',
#   u'views': u'5699',
#   u'width_m': u'340'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-02-28 12:05:01',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1393550063',
#   u'description': {u'_content': u'Title: Aylmerton Public School - Result of break in at Colo Vale Public School which occurred 15/05/1927. \nPolice reports state that a man named John William Croft recently discharged from Bowral Hospital broke into building intent on exacting revenge on government left message &quot;Treated like a dog, if you want to die go to Bowral Hospital and get starved 7:30pm 15/05/27 Australia is rotten&quot;. Attempts to find the man were unsuccessful. \nDated: 16/05/1927\nDigital ID: <a href="http://investigator.records.nsw.gov.au/asp/photosearch/photo.asp?15051_a047_000486" rel="nofollow">15051_a047_000486</a>\nRights: No known copyright restrictions  <a href="http://www.records.nsw.gov.au/about-us/rights-and-permissions" rel="nofollow">www.records.nsw.gov.au/about-us/rights-and-permissions</a>\n\n\nWe\'d love to <a href="http://www.records.nsw.gov.au/contact-us" rel="nofollow">hear from you</a> if you use our photos/documents.\n\n\nMany other photos in our collection are available to view and browse on our website using <a href="http://investigator.records.nsw.gov.au/asp/photosearch/photosearch.asp" rel="nofollow">Photo Investigator</a>.'},
#   u'farm': 8,
#   u'height_m': u'500',
#   u'id': u'12825039943',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1394716354',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'27331537@N06',
#   u'ownername': u'State Records NSW',
#   u'secret': u'7fd28ae329',
#   u'server': u'7427',
#   u'tags': u'school blackandwhite crime archives newsouthwales breakin staterecordsnsw vision:text=0921 vision:outdoor=0837',
#   u'title': u'Aylmerton Public School - Result of break in at Colo Vale Public School which occurred 15/05/1927',
#   u'url_m': u'http://farm8.staticflickr.com/7427/12825039943_7fd28ae329.jpg',
#   u'views': u'1716',
#   u'width_m': u'325'},
#  {u'accuracy': u'16',
#   u'context': 0,
#   u'datetaken': u'1903-01-01 00:00:00',
#   u'datetakengranularity': u'6',
#   u'dateupload': u'1392926946',
#   u'description': {u'_content': u'<strong>Creator:</strong>  Unidentified\n\n<strong>Location:</strong> Brisbane, Queensland\n\n<strong>Description:</strong>An animal tableau, Wirth\'s Circus. Herr Paul, animal trainer. [Description supplied with photograph] The tableau includes a horse, dog, goat and two lions? posing on stands behind the trainer.\n\nView this image at the State Library of Queensland: <a href="http://hdl.handle.net/10462/deriv/54886" rel="nofollow">hdl.handle.net/10462/deriv/54886</a>\nInformation about State Library of Queensland\u2019s collection: <a href="http://www.slq.qld.gov.au/resources/picture-queensland" rel="nofollow">www.slq.qld.gov.au/resources/picture-queensland</a>'},
#   u'farm': 6,
#   u'geo_is_contact': 0,
#   u'geo_is_family': 0,
#   u'geo_is_friend': 0,
#   u'geo_is_public': 1,
#   u'height_m': u'276',
#   u'id': u'12662111824',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1393436916',
#   u'latitude': -27.46888,
#   u'license': u'7',
#   u'longitude': 153.022827,
#   u'owner': u'32605636@N06',
#   u'ownername': u'State Library of Queensland, Australia',
#   u'place_id': u'khXM8m9QU7ofBD4U',
#   u'secret': u'f9c9fa8a68',
#   u'server': u'5473',
#   u'tags': u'horse dog circus tiger lion goat circusanimals animaltrainer herrpaul wirthscircus vision:outdoor=0984',
#   u'title': u'Tableau of circus animals Brisbane 1903',
#   u'url_m': u'http://farm6.staticflickr.com/5473/12662111824_f9c9fa8a68.jpg',
#   u'views': u'2686',
#   u'width_m': u'500',
#   u'woeid': u'1100661'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-03-14 16:14:36',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1392850286',
#   u'description': {u'_content': u'March Day Lecture - To all those in Sydney - Join us at History House, 133 Macquarie Street, Sydney on Wednesday 5th March at 1pm for the next instalment in the RAHS\' popular Day Lecture Series. \n\nCost: Free\nBookings Essential: Call (02) 9247 8001 or email: admin@rahs.org.au\nEvent information: \n\n<a href="http://www.rahs.org.au/ai1ec_event/rahs-day-lecture-four-legs-good-no-legs-bad-dogs-snakes-doctors-and-police-in-colonial-australia/" rel="nofollow">www.rahs.org.au/ai1ec_event/rahs-day-lecture-four-legs-go...</a>\n\nAbout the speaker: Peter Hobbins is an historian of science and medicine who recently completed his PhD on venomous animals in colonial Australia and New Zealand.\n\nAnimals were everywhere in colonial Australia, but few creatures travelled so far in public opinion as dogs and snakes. Valued for their hunting prowess, dogs were perhaps the earliest beasts transformed by white settlers to suit their new environment and also among the first to proliferate beyond the control of colonists. As early as the 1820\u2019s, hounds gone \u2018wild\u2019 posed a significant threat to public order and livestock, prompting some of the world\u2019s earliest Dog Acts to corral, castrate and kill unwanted canines. Over the same period, Australia\u2019s indigenous snakes likewise became vilified. Initially considered benign, the colonists\u2019 observations of snakebite in their animals \u2013 as much as in humans \u2013 led them to fear and loathe local serpents. Dogs, in particular, were frequent victims of snakebite.\n\nBy the 1850\u2019s, such occurrences were no longer accidental. Roving snake showmen and antidote sellers employed \u2018curs\u2019 and pets alike to demonstrate the fatal effects of envenomation and, all going well, the efficacy of their remedies. Into the 1880\u2019s, the frequency and prominence of these lay experiments set public standards of proof, which materially affected the claims and conduct of colonial doctors in treating snakebite. Being responsible for controlling unlicensed strays, regulating public performances and recording violent deaths, colonial police were constantly at the centre of these exhibitions of animal suffering. Indeed, into the twentieth century, constables and magistrates played significant roles in establishing which Australian snakes were \u2018dangerous\u2019 and which treatments appeared effective.'},
#   u'farm': 6,
#   u'height_m': u'360',
#   u'id': u'12644208044',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1395950309',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'69269002@N04',
#   u'ownername': u'Royal Australian Historical Society',
#   u'secret': u'8564402feb',
#   u'server': u'5510',
#   u'tags': u'newzealand dogs colonial hunting police australia settlers doctors livestock snakes peterhobbins',
#   u'title': u'James Bray - fight between black snake and blue-tongued lizard - State Library of NSW PXA 193',
#   u'url_m': u'http://farm6.staticflickr.com/5510/12644208044_8564402feb.jpg',
#   u'views': u'1228',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2014-02-20 09:50:05',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1392850287',
# ...
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1386572022',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life&quot;\n<strong>Author</strong>: Stables, Gordon\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12624.i.7.&quot;\n<strong>Page</strong>: 43\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1884\n<strong>Publisher</strong>: Partridge &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003471451\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003471451&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003471451&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003471451">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1884">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 6,
#   u'height_m': u'500',
#   u'id': u'11285469613',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1386881374',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'0efc37f7dd',
#   u'server': u'5480',
#   u'tags': u'medium publicdomain page43 vol0 bldigital vision:text=0618 mechanicalcurator pubplacelondon date1884 vision:outdoor=093 stablesgordon sysnum003471451 imagesfrombook003471451 imagesfromvolume0034714510',
#   u'title': u"Image taken from page 43 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'",
#   u'url_m': u'http://farm6.staticflickr.com/5480/11285469613_0efc37f7dd.jpg',
#   u'views': u'251',
#   u'width_m': u'494'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-09 06:40:14',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1386571214',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life&quot;\n<strong>Author</strong>: Stables, Gordon\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12624.i.7.&quot;\n<strong>Page</strong>: 288\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1884\n<strong>Publisher</strong>: Partridge &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003471451\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003471451&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003471451&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003471451">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1884">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 8,
#   u'height_m': u'481',
#   u'id': u'11285335503',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1386881374',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'd7f4e3d1b4',
#   u'server': u'7350',
#   u'tags': u'medium publicdomain vol0 page288 bldigital vision:text=0621 mechanicalcurator pubplacelondon date1884 vision:outdoor=0957 stablesgordon sysnum003471451 imagesfrombook003471451 imagesfromvolume0034714510',
#   u'title': u"Image taken from page 288 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'",
#   u'url_m': u'http://farm8.staticflickr.com/7350/11285335503_d7f4e3d1b4.jpg',
#   u'views': u'206',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-09 06:49:11',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1386571751',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life&quot;\n<strong>Author</strong>: Stables, Gordon\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12624.i.7.&quot;\n<strong>Page</strong>: 151\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1884\n<strong>Publisher</strong>: Partridge &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003471451\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003471451&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003471451&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003471451">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1884">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 3,
#   u'height_m': u'500',
#   u'id': u'11285424033',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1386881374',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'2cf5d0cb44',
#   u'server': u'2819',
#   u'tags': u'medium publicdomain page151 vol0 bldigital vision:text=0634 mechanicalcurator pubplacelondon date1884 vision:outdoor=0919 stablesgordon sysnum003471451 imagesfrombook003471451 imagesfromvolume0034714510',
#   u'title': u"Image taken from page 151 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'",
#   u'url_m': u'http://farm3.staticflickr.com/2819/11285424033_2cf5d0cb44.jpg',
#   u'views': u'246',
#   u'width_m': u'472'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-09 06:09:23',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1386569363',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life&quot;\n<strong>Author</strong>: Stables, Gordon\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12624.i.7.&quot;\n<strong>Page</strong>: 226\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1884\n<strong>Publisher</strong>: Partridge &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003471451\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003471451&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003471451&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003471451">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1884">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 4,
#   u'height_m': u'407',
#   u'id': u'11285014313',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1386881373',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'df8b402834',
#   u'server': u'3826',
#   u'tags': u'medium publicdomain vol0 page226 vision:people=099 vision:face=099 bldigital vision:text=0555 mechanicalcurator pubplacelondon date1884 vision:outdoor=0957 stablesgordon sysnum003471451 imagesfrombook003471451 imagesfromvolume0034714510',
#   u'title': u"Image taken from page 226 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'",
#   u'url_m': u'http://farm4.staticflickr.com/3826/11285014313_df8b402834.jpg',
#   u'views': u'256',
#   u'width_m': u'500'},
#  {u'accuracy': 0,
#   u'context': 0,
#   u'datetaken': u'2013-12-09 05:58:04',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1386568684',
#   u'description': {u'_content': u'Image taken from:\n\n<strong>Title</strong>: &quot;Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life&quot;\n<strong>Author</strong>: Stables, Gordon\n<strong>Shelfmark</strong>: &quot;British Library HMNTS 12624.i.7.&quot;\n<strong>Page</strong>: 158\n<strong>Place of Publishing</strong>: London\n<strong>Date of Publishing</strong>: 1884\n<strong>Publisher</strong>: Partridge &amp; Co.\n<strong>Issuance</strong>: monographic\n<strong>Identifier</strong>: 003471451\n\n\n<em>Note: The colours, contrast and appearance of these illustrations are unlikely to be true to life. They are derived from scanned images that have been enhanced for machine interpretation and have been altered from their originals.</em>\n\n<strong>If you wish to purchase a high quality copy of the page that this image is drawn from, please order it <a href="http://bit.ly/1b3VS7i" target="_blank" rel="nofollow">here</a>.</strong> Please note that you will need to enter details from the above list - such as the shelfmark, the page, the book\'s volume and so on - when filling out your order.\n\n<em>Following <a href="http://explore.bl.uk/primo_library/libweb/action/search.do?cs=frb&amp;doc=BLL01003471451&amp;dscnt=1&amp;scp.scps=scope:(BLCONTENT)&amp;frbg=&amp;tab=local_tab&amp;srt=rank&amp;ct=search&amp;mode=Basic&amp;dum=true&amp;tb=t&amp;indx=1&amp;vl(freeText0)=003471451&amp;fn=search&amp;vid=BLVU1" rel="nofollow">this</a> or the link above will take you to the British Library\'s integrated catalogue. You will be able to download a PDF of the book this image is taken from, as well as view the pages up close with the \'itemViewer\'. Click on the \'related items\' to search for the electronic version of this work.</em>\n\nClick <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/sysnum003471451">here</a></strong> to see all the illustrations in this book and click <strong><a href="http://www.flickr.com/photos/britishlibrary/tags/date1884">here</a></strong> to browse other illustrations published in books in the same year. Please click on the tags shown on the right-hand side for other ways to browse the illustrations.\n\n'},
#   u'farm': 3,
#   u'height_m': u'325',
#   u'id': u'11284889593',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'lastupdate': u'1386881373',
#   u'latitude': 0,
#   u'license': u'7',
#   u'longitude': 0,
#   u'owner': u'12403504@N02',
#   u'ownername': u'The British Library',
#   u'secret': u'643420a9cf',
#   u'server': u'2846',
#   u'tags': u'medium publicdomain vol0 page158 vision:text=057 bldigital mechanicalcurator pubplacelondon date1884 vision:outdoor=0858 vision:car=0528 stablesgordon sysnum003471451 imagesfrombook003471451 imagesfromvolume0034714510',
#   u'title': u"Image taken from page 158 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'",
#   u'url_m': u'http://farm3.staticflickr.com/2846/11284889593_643420a9cf.jpg',
#   u'views': u'175',
#   u'width_m': u'500'}]

# %%
photos = get_photos_static_urls(flickr.photos_search(
        tag_mode='any',
        tags='dog, puppy',
        license='7',
        format='json'))

HTML(template.render(items=photos[:20]))
# Out:
# <style>
#   .wrap img {
#     margin-left: 0px;
#     margin-right: 0px;
#     display: inline-block;
#     width: 150px;
#   }
#
# .wrap {
#    /* Prevent vertical gaps */
#    line-height: 0;
#
#    -webkit-column-count: 5;
#    -webkit-column-gap:   0px;
#    -moz-column-count:    5;
#    -moz-column-gap:      0px;
#    column-count:         5;
#    column-gap:           0px;
#
# }
# .wrap img {
#   /* Just in case there are inline attributes */
#   width: 100% !important;
#   height: auto !important;
# }
#
# </style>
#
# <div class="wrap">
#  <img src="http://farm6.staticflickr.com/5538/11292885426_f09443f484_m.jpg"/><img src="http://farm8.staticflickr.com/7373/11222803106_0963978e49_m.jpg"/><img src="http://farm6.staticflickr.com/5483/11062816216_7f41ab7c0e_m.jpg"/><img src="http://farm6.staticflickr.com/5495/11007099313_32784f940a_m.jpg"/><img src="http://farm6.staticflickr.com/5473/12662111824_f9c9fa8a68_m.jpg"/><img src="http://farm6.staticflickr.com/5472/12609397644_f232710c3e_m.jpg"/><img src="http://farm8.staticflickr.com/7315/12584715825_78733cd4b1_m.jpg"/><img src="http://farm4.staticflickr.com/3764/12525423004_f8233d4be7_m.jpg"/><img src="http://farm8.staticflickr.com/7302/12513169314_c52b1c029f_m.jpg"/><img src="http://farm8.staticflickr.com/7345/12459205903_be49135916_m.jpg"/><img src="http://farm4.staticflickr.com/3737/12218739974_2d48d2ea4d_m.jpg"/><img src="http://farm4.staticflickr.com/3810/12115019935_66e0892107_m.jpg"/><img src="http://farm8.staticflickr.com/7313/11987368804_fce65e4cc0_m.jpg"/><img src="http://farm4.staticflickr.com/3748/11733331783_0434eaec39_m.jpg"/><img src="http://farm4.staticflickr.com/3726/11254275105_115b3cbaeb_m.jpg"/><img src="http://farm4.staticflickr.com/3759/11432700246_c6a606d770_m.jpg"/><img src="http://farm3.staticflickr.com/2851/11403109745_038200bd7b_m.jpg"/><img src="http://farm6.staticflickr.com/5474/11307072035_24ee044e37_m.jpg"/><img src="http://farm6.staticflickr.com/5492/11307096366_2911dbd2ff_m.jpg"/><img src="http://farm3.staticflickr.com/2878/11306044406_7c4a61b741_m.jpg"/>
# </div>
