# %%
"""
This notebook includes all the main functions we created to parse Flickr photo data
"""

# %%
import flickrapi
from flickrapi import shorturl
from IPython.display import display, Image
import json

APIKEY = "800f28ae42a58a95f0005fb0fe022a78"

flickr = flickrapi.FlickrAPI(APIKEY)

# %%
from IPython.display import HTML
from jinja2 import Template

CSS = """
<style>
  .wrap img {
    margin-left: 0px;
    margin-right: 0px;
    display: inline-block;
    width: 150px;
  }
  
.wrap {
   /* Prevent vertical gaps */
   line-height: 0;
   
   -webkit-column-count: 5;
   -webkit-column-gap:   0px;
   -moz-column-count:    5;
   -moz-column-gap:      0px;
   column-count:         5;
   column-gap:           0px;
   
}
.wrap img {
  /* Just in case there are inline attributes */
  width: 100% !important;
  height: auto !important;
}

</style>
"""

IMAGES_TEMPLATE = CSS + """
<div class="wrap">
 {% for item in items %}<img src="{{item}}"/>{% endfor %}
</div>
"""

template = Template(IMAGES_TEMPLATE)

# To display photos in HTML, use:

# photos = get_photos_static_urls(flickr.photos_search(
#     tag_mode='any',
#     text='uc berkeley',
#     format='json'))

#   template = Template(IMAGES_TEMPLATE)
#   HTML(template.render(items=photos[:30]))  # shows first 30 photos

# %%
"""
Given a flickr api search query with format='json', returns the data in actual json format
flickr_search_response = flickr.photos_search(
        format='json', 
        ...
    )
"""
def get_json(flickr_search_response):
    json_string = flickr_search_response[14:-1]
    return json.loads(json_string)

"""
Returns the json data including pages, total photo count, and list of photos
"""
def get_data(flickr_search_response):
    return get_json(flickr_search_response)['photos']

"""
Returns the json list of photos

u'photo': [{u'farm': 6,
   u'id': u'11292885426',
   u'isfamily': 0,
   u'isfriend': 0,
   u'ispublic': 1,
   u'owner': u'12403504@N02',
   u'secret': u'f09443f484',
   u'server': u'5538',
   u'title': u"Image taken from page 392 of 'Northward over the \u201cGreat Ice\u201d: a 
    narrative of life and work along the shores and upon the interior ice-cap of Northern 
    Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations'"},
"""
def get_photos(flickr_search_response):
    return get_json(flickr_search_response)['photos']['photo']

"""
Returns array of Flikr photo URLs -- opens in Flickr photo viewer
"""
def get_photo_urls(flickr_search_response):
    photo_list = get_photos(flickr_search_response)
    photo_urls = []
    for photo in photo_list:
        photo_urls.append(flickrapi.shorturl.url(photo['id']))
    return photo_urls

"""
Returns array of direct photo jpg URLs
"""
def get_photos_static_urls(flickr_search_response):
    photo_list = get_photos(flickr_search_response)
    photo_urls = []
    for photo in photo_list:
        # http://farm{farm-id}.staticflickr.com/{server-id}/{id}_{o-secret}_o.(jpg|gif|png)
        # http://farm1.staticflickr.com/2/1418878_1e92283336_m.jpg
        size = "m" # m, z, b
        # for list of sizes see https://www.flickr.com/services/api/misc.urls.html
        url = "http://farm" + str(photo['farm']) + ".staticflickr.com/" + photo['server'] + "/" + photo['id'] + "_" + photo['secret'] +  "_" + size + ".jpg"   
        photo_urls.append(url)
    return photo_urls

"""
Returns the count of results
"""
def get_count(flickr_search_response):
    return get_json(flickr_search_response)['photos']['total']

# %%
get_count(flickr.photos_search(
        tag_mode='any',
        tag='dog',
        license='7',
        format='json'))
# Out:
# u'858086'

# %%
get_data(flickr.photos_search(
        text='dog',
        license='7',
        format='json'))
# Out:
# {u'page': 1,
#  u'pages': 21,
#  u'perpage': 100,
#  u'photo': [{u'farm': 6,
#    u'id': u'11292885426',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'f09443f484',
#    u'server': u'5538',
#    u'title': u"Image taken from page 392 of 'Northward over the \u201cGreat Ice\u201d: a narrative of life and work along the shores and upon the interior ice-cap of Northern Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations'"},
#   {u'farm': 3,
#    u'id': u'13779194673',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'8623220@N02',
#    u'secret': u'2d7d694e97',
#    u'server': u'2902',
#    u'title': u'German Red Cross Dogs going to front (LOC)'},
#   {u'farm': 4,
#    u'id': u'11239342056',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'0f6756fee1',
#    u'server': u'3719',
#    u'title': u"Image taken from page 346 of 'Voyage et aventures autour du monde de Robert Kergorie\u0300u. [With plates.]'"},
#   {u'farm': 8,
#    u'id': u'13739127853',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'24231108@N08',
#    u'secret': u'5edd7ec863',
#    u'server': u'7225',
#    u'title': u'N_92_1_317'},
#   {u'farm': 8,
#    u'id': u'13739078745',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'24231108@N08',
#    u'secret': u'd6ed8778be',
#    u'server': u'7453',
#    u'title': u'N_92_1_375'},
#   {u'farm': 3,
#    u'id': u'13739122703',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'24231108@N08',
#    u'secret': u'500b955113',
#    u'server': u'2895',
#    u'title': u'N_92_1_374'},
#   {u'farm': 3,
#    u'id': u'13739084183',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'24231108@N08',
#    u'secret': u'649bc64d91',
#    u'server': u'2902',
#    u'title': u'N_92_1_286'},
#   {u'farm': 8,
#    u'id': u'13739443014',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'24231108@N08',
#    u'secret': u'6da02408b1',
#    u'server': u'7214',
#    u'title': u'N_92_1_287'},
#   {u'farm': 8,
#    u'id': u'13708316534',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'29454428@N08',
#    u'secret': u'96b8dcd521',
#    u'server': u'7060',
#    u'title': u'Botanical Gardens, Sydney, [showing Hunstman and Dogs sculpture] c. 1900-1910'},
#   {u'farm': 3,
#    u'id': u'13630141093',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'49487266@N07',
#    u'secret': u'04a7dc8c9d',
#    u'server': u'2832',
#    u'title': u'AL247-016'},
#   {u'farm': 8,
#    u'id': u'13453086375',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'39758725@N03',
#    u'secret': u'34f699868a',
#    u'server': u'7065',
#    u'title': u'Automobiles'},
#   {u'farm': 8,
#    u'id': u'13310441234',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'95711690@N03',
#    u'secret': u'f50fe2c70f',
#    u'server': u'7077',
#    u'title': u'Brebner family'},
#   {u'farm': 6,
#    u'id': u'11062816216',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'7f41ab7c0e',
#    u'server': u'5483',
#    u'title': u"Image taken from page 213 of 'Charley Wag, the new Jack Sheppard. A new and intensely exciting real-life romance'"},
#   {u'farm': 8,
#    u'id': u'11222803106',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'0963978e49',
#    u'server': u'7373',
#    u'title': u"Image taken from page 72 of 'Always in the Way; ... With ... illustrations, etc. (New edition.)'"},
#   {u'farm': 4,
#    u'id': u'13214078914',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'37199428@N06',
#    u'secret': u'a595a207d8',
#    u'server': u'3770',
#    u'title': u"Farmers helping each other to round up Glan Meryn's sheep, Machynlleth"},
#   {u'farm': 8,
#    u'id': u'13116456285',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'32605636@N06',
#    u'secret': u'00c54146e1',
#    u'server': u'7328',
#    u'title': u'Shark caught in Brisbane River at Hamilton, Brisbane, circa 1937.'},
#   {u'farm': 6,
#    u'id': u'12484377143',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'25053835@N03',
#    u'secret': u'6a56d9343f',
#    u'server': u'5527',
#    u'title': u'Wynne Sharples Ballinger (1923-2008)'},
#   {u'farm': 3,
#    u'id': u'12836314013',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'8623220@N02',
#    u'secret': u'14504fc3b3',
#    u'server': u'2836',
#    u'title': u"Red Cross Dog, Gov.'s Isl. (LOC)"},
#   {u'farm': 3,
#    u'id': u'12836225855',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'8623220@N02',
#    u'secret': u'e6341c0fca',
#    u'server': u'2810',
#    u'title': u"Red Cross Dog, Gov.'s Isl. (LOC)"},
#   {u'farm': 6,
#    u'id': u'11007099313',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'32784f940a',
#    u'server': u'5495',
#    u'title': u"Image taken from page 2 of '[The Castles and Abbeys of England ... Illustrated by ... engravings.]'"},
#   {u'farm': 6,
#    u'id': u'11222889566',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'cbfdefd1bc',
#    u'server': u'5484',
#    u'title': u"Image taken from page 243 of 'A Dog of Flanders and other stories. By Ouida. A new edition, etc'"},
#   {u'farm': 8,
#    u'id': u'12825039943',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'27331537@N06',
#    u'secret': u'7fd28ae329',
#    u'server': u'7427',
#    u'title': u'Aylmerton Public School - Result of break in at Colo Vale Public School which occurred 15/05/1927'},
#   {u'farm': 6,
#    u'id': u'12662111824',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'32605636@N06',
#    u'secret': u'f9c9fa8a68',
#    u'server': u'5473',
#    u'title': u'Tableau of circus animals Brisbane 1903'},
#   {u'farm': 3,
#    u'id': u'12644206464',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'6125ca5648',
#    u'server': u'2807',
#    u'title': u'Police News 24 March 1877'},
#   {u'farm': 6,
#    u'id': u'12644208044',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'8564402feb',
#    u'server': u'5510',
#    u'title': u'James Bray - fight between black snake and blue-tongued lizard - State Library of NSW PXA 193'},
#   {u'farm': 8,
#    u'id': u'12644216394',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'0822e63d42',
#    u'server': u'7296',
#    u'title': u'Snake adventures in the bush - Illustrated Australian News, 16 May 1883'},
#   {u'farm': 4,
#    u'id': u'12643720845',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'4df48d115f',
#    u'server': u'3809',
#    u'title': u'Neville Cayley - kookaburra and snake - National Library of Australia image an13886742'},
#   {u'farm': 3,
#    u'id': u'12643854003',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'ed5b3efa68',
#    u'server': u'2888',
#    u'title': u'Detail from William Strutt - Black Thursday, 1851 - painted 1864 - State Library of Victoria'},
#   {u'farm': 6,
#    u'id': u'12644206864',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'2e7188e8c3',
#    u'server': u'5515',
#    u'title': u'Venom milking apparatus designed by James Bray - Chemist and Druggist of Australasia, 1903'},
#   {u'farm': 8,
#    u'id': u'12644205864',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'f08affaebd',
#    u'server': u'7333',
#    u'title': u'William Strutt - Black Thursday, 1851 - painted 1864 - State Library of Victoria'},
#   {u'farm': 6,
#    u'id': u'12609397644',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'37547255@N08',
#    u'secret': u'f232710c3e',
#    u'server': u'5472',
#    u'title': u'Group portrait, ca. 1897-1905.'},
#   {u'farm': 3,
#    u'id': u'12599532663',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'20ba5df5f4',
#    u'server': u'2892',
#    u'title': u'Melbourne Gaol experiments - Australasian Sketcher 17 Feb 1877  p184'},
#   {u'farm': 3,
#    u'id': u'12599853634',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'456ffd83d0',
#    u'server': u'2842',
#    u'title': u'Commencement of the snake season 1877 - State Library of Victoria image mp016818'},
#   {u'farm': 8,
#    u'id': u'12599852994',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'c43b685d36',
#    u'server': u'7363',
#    u'title': u'His first snake - Australasian Sketcher 24 January 1889'},
#   {u'farm': 6,
#    u'id': u'12599853144',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'd288b8de36',
#    u'server': u'5511',
#    u'title': u'Dangerous Snakes of Victoria 1877- Museum Victoria collection'},
#   {u'farm': 4,
#    u'id': u'12599427165',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'48563dda35',
#    u'server': u'3833',
#    u'title': u'Thomas Skottowe - Australian snakes 1810 - Mitchell Library image SAFE PXA 555 a642053h'},
#   {u'farm': 4,
#    u'id': u'12599427515',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'0a158dea90',
#    u'server': u'3787',
#    u'title': u'Snake hunt on the Murray - National Library of Australia image an24648179'},
#   {u'farm': 8,
#    u'id': u'12599429995',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'84e520a267',
#    u'server': u'7392',
#    u'title': u'George Kilburne - Dog attacking a snake 1883 - National Library of Australia image an5714624'},
#   {u'farm': 8,
#    u'id': u'12599856284',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'69269002@N04',
#    u'secret': u'4c59389a3a',
#    u'server': u'7293',
#    u'title': u'Christmas on the Diggings, or the Unwelcome Visitor who Came Uninvited - National Library of Australia image an7096208-2'},
#   {u'farm': 8,
#    u'id': u'12584715825',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'78733cd4b1',
#    u'server': u'7315',
#    u'title': u'Taking a break...'},
#   {u'farm': 4,
#    u'id': u'12525423004',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'95711690@N03',
#    u'secret': u'f8233d4be7',
#    u'server': u'3764',
#    u'title': u'Group posing on fence'},
#   {u'farm': 8,
#    u'id': u'12513169314',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'33147718@N05',
#    u'secret': u'c52b1c029f',
#    u'server': u'7302',
#    u'title': u'Portrait of a performer in costume holding a small dog'},
#   {u'farm': 8,
#    u'id': u'12459247853',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'1e2970ddd8',
#    u'server': u'7371',
#    u'title': u"Book of Hours - caption: 'The Annunciation; a cat and dog play in the foreground; inhabited initial and decorated border with foliage, birds and figures'"},
#   {u'farm': 8,
#    u'id': u'12459205903',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'be49135916',
#    u'server': u'7345',
#    u'title': u"Rowlandson's characteristic Sketches of the Lower Orders, intended as a companion to the New Picture of London: consisting of fifty-four plates ... coloured.  - caption: ''Poodles'. Three people admiring some puppies.'"},
#   {u'farm': 4,
#    u'id': u'12458771655',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'a265f6225b',
#    u'server': u'3762',
#    u'title': u"Tilliot Hours - caption: 'Dives and Lazarus'"},
#   {u'farm': 8,
#    u'id': u'12350607085',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'39758725@N03',
#    u'secret': u'ff7478d39c',
#    u'server': u'7426',
#    u'title': u'Two couples'},
#   {u'farm': 6,
#    u'id': u'12310728224',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'41131493@N06',
#    u'secret': u'4c5ed70f05',
#    u'server': u'5484',
#    u'title': u'Mexican Cart and Burro.'},
#   {u'farm': 4,
#    u'id': u'12218739974',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'2d48d2ea4d',
#    u'server': u'3737',
#    u'title': u'Silence is requested!'},
#   {u'farm': 4,
#    u'id': u'12115019935',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'66e0892107',
#    u'server': u'3810',
#    u'title': u'Next stop, America!'},
#   {u'farm': 4,
#    u'id': u'12114199475',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'25b67acc5f',
#    u'server': u'3800',
#    u'title': u'Norges flagg plantet paa Sydpolen. Sl\xe6defe\xe6rden mot Sydpolen - H\xf8sten 1911'},
#   {u'farm': 4,
#    u'id': u'12114856506',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'32aa2df5ea',
#    u'server': u'3773',
#    u'title': u'"Mauds" skrog bygges inne med sn\xf8blokker etter at fart\xf8yet har frosset fast i isen, 1918'},
#   {u'farm': 6,
#    u'id': u'12114598254',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'92fd3a2859',
#    u'server': u'5528',
#    u'title': u'Bj\xf8rneskinn hengende p\xe5 hjell, juni 1919'},
#   {u'farm': 6,
#    u'id': u'12114495223',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'dc625c6615',
#    u'server': u'5499',
#    u'title': u'En inuitkvinne med hundehvalp foran et telt, 1903-1906'},
#   {u'farm': 6,
#    u'id': u'12114495993',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'3084beda16',
#    u'server': u'5497',
#    u'title': u'Ekspedisjon med sleder og hundespann, 1911-1912'},
#   {u'farm': 8,
#    u'id': u'12114599724',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'f86ba1d83c',
#    u'server': u'7360',
#    u'title': u'Sledene gj\xf8res klare til Harald Ulrik Sverdrup og Paul Knudsens ekspedisjon, 1919'},
#   {u'farm': 4,
#    u'id': u'12114854176',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'b69784441c',
#    u'server': u'3707',
#    u'title': u'Den f\xf8rste leirplassen p\xe5 isen ved Hvalbukta, januar 1911'},
#   {u'farm': 4,
#    u'id': u'12098668645',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'a9858879c6',
#    u'server': u'3746',
#    u'title': u'The Kennels at Rockingham Estate'},
#   {u'farm': 6,
#    u'id': u'12001586914',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'99278405@N04',
#    u'secret': u'7f0722b5a6',
#    u'server': u'5474',
#    u'title': u'Menu, Ritz Old Poodle Dog, San Francisco [open]'},
#   {u'farm': 4,
#    u'id': u'12001524353',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'99278405@N04',
#    u'secret': u'5262695bce',
#    u'server': u'3680',
#    u'title': u'Wine list, Ritz Old Poodle Dog, San Francisco'},
#   {u'farm': 6,
#    u'id': u'12001589954',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'31846825@N04',
#    u'secret': u'4c85f4b2fc',
#    u'server': u'5510',
#    u'title': u'Martin Luther King Jr. in St. Augustine, Florida'},
#   {u'farm': 8,
#    u'id': u'12002040576',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'99278405@N04',
#    u'secret': u'8e513e5bf0',
#    u'server': u'7359',
#    u'title': u'Menu, Ritz Old Poodle Dog, San Francisco [cover]'},
#   {u'farm': 8,
#    u'id': u'11987368804',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'27331537@N06',
#    u'secret': u'fce65e4cc0',
#    u'server': u'7313',
#    u'title': u'S.S. Adelaide'},
#   {u'farm': 4,
#    u'id': u'11927678175',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'a2e140e503',
#    u'server': u'3679',
#    u'title': u'Made it, Ma! Top of the world!'},
#   {u'farm': 4,
#    u'id': u'11733331783',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'8623220@N02',
#    u'secret': u'0434eaec39',
#    u'server': u'3748',
#    u'title': u'Olive Thomas (LOC)'},
#   {u'farm': 4,
#    u'id': u'11711236916',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'31846825@N04',
#    u'secret': u'4215b6c548',
#    u'server': u'3715',
#    u'title': u'Koreshans on the beach in Naples, Florida'},
#   {u'farm': 6,
#    u'id': u'11704594433',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'37199428@N06',
#    u'secret': u'4ce24535af',
#    u'server': u'5530',
#    u'title': u"Farmers' Hunt in Llanbrynmair on New Year's Day"},
#   {u'farm': 3,
#    u'id': u'11511802635',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'ce9f70783a',
#    u'server': u'2889',
#    u'title': u'Mannskapet tar en hvil om bord p\xe5 \xabFram\xbbs akterdekk, juni/juli 1894'},
#   {u'farm': 4,
#    u'id': u'11254275105',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'115b3cbaeb',
#    u'server': u'3726',
#    u'title': u"Image taken from page 38 of 'Playtime Rhymes: verses for the children ... Illustrated by Hugh Wallis & Dorothy Horsnaill'"},
#   {u'farm': 4,
#    u'id': u'11432700246',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'47290943@N03',
#    u'secret': u'c6a606d770',
#    u'server': u'3759',
#    u'title': u'One Man and his Dog'},
#   {u'farm': 3,
#    u'id': u'11403109745',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'95772747@N07',
#    u'secret': u'038200bd7b',
#    u'server': u'2851',
#    u'title': u'Greenland in the late 19th-early 20th century'},
#   {u'farm': 3,
#    u'id': u'11354103533',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'31846825@N04',
#    u'secret': u'0c7e04d148',
#    u'server': u'2825',
#    u'title': u"Snowman's Holiday"},
#   {u'farm': 3,
#    u'id': u'11335890226',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'48220291@N04',
#    u'secret': u'd42b6ebab8',
#    u'server': u'2860',
#    u'title': u'Sledene gj\xf8res klare til Harald Ulrik Sverdrup og Paul Knudsens ekspedisjon'},
#   {u'farm': 8,
#    u'id': u'11313192224',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'52529054@N06',
#    u'secret': u'5b1aa80c25',
#    u'server': u'7310',
#    u'title': u'School picnic'},
#   {u'farm': 6,
#    u'id': u'11307072035',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'24ee044e37',
#    u'server': u'5474',
#    u'title': u"Image taken from page 105 of 'Illustrated Poems and Songs for Young People. Edited by Mrs. Sale Barker'"},
#   {u'farm': 4,
#    u'id': u'11307154864',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'8642483054',
#    u'server': u'3781',
#    u'title': u"Image taken from page 68 of 'Nimrod in the North, or hunting and fishing adventures in the Arctic regions'"},
#   {u'farm': 6,
#    u'id': u'11307096366',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'2911dbd2ff',
#    u'server': u'5492',
#    u'title': u"Image taken from page 32 of 'Illustrated Poems and Songs for Young People. Edited by Mrs. Sale Barker'"},
#   {u'farm': 6,
#    u'id': u'11306981253',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'deaba67558',
#    u'server': u'5481',
#    u'title': u"Image taken from page 113 of '[Our own country. Descriptive, historical, pictorial.]'"},
#   {u'farm': 6,
#    u'id': u'11306415784',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'069fce7c0b',
#    u'server': u'5495',
#    u'title': u"Image taken from page 143 of '[Somerville's Chase.]'"},
#   {u'farm': 3,
#    u'id': u'11306044406',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'7c4a61b741',
#    u'server': u'2878',
#    u'title': u"Image taken from page 330 of 'The Children's Fairy Geography: or, a Merry Trip ... Eighth thousand'"},
#   {u'farm': 8,
#    u'id': u'11303962986',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'fbd8c52b12',
#    u'server': u'7328',
#    u'title': u"Image taken from page 252 of 'Humorous Poems ... With a preface by A. Ainger, and ... illustrations by C. E. Brock. L.P'"},
#   {u'farm': 6,
#    u'id': u'11303641914',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'9c888a0856',
#    u'server': u'5511',
#    u'title': u"Image taken from page 261 of 'Humorous Poems ... With a preface by A. Ainger, and ... illustrations by C. E. Brock. L.P'"},
#   {u'farm': 8,
#    u'id': u'11298261033',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'1aaceb185d',
#    u'server': u'7397',
#    u'title': u"Image taken from page 253 of '(The Year Book of British Columbia Compendium.) Compiled from the Year Book of British Columbia ... To which is added a chapter ... respecting the Canadian Yukon and Northern territory generally'"},
#   {u'farm': 3,
#    u'id': u'11298182085',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'388bd87aed',
#    u'server': u'2852',
#    u'title': u"Image taken from page 14 of 'Across England in a Dog-Cart from London to St. Davids and back ... With ... illustrations by the author, etc'"},
#   {u'farm': 4,
#    u'id': u'11297958664',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'2f203e63c4',
#    u'server': u'3721',
#    u'title': u"Image taken from page 17 of 'Across England in a Dog-Cart from London to St. Davids and back ... With ... illustrations by the author, etc'"},
#   {u'farm': 4,
#    u'id': u'11296974393',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'e710c39804',
#    u'server': u'3707',
#    u'title': u"Image taken from page 25 of 'Across England in a Dog-Cart from London to St. Davids and back ... With ... illustrations by the author, etc'"},
#   {u'farm': 6,
#    u'id': u'11292987666',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'c65b9e6d7b',
#    u'server': u'5489',
#    u'title': u"Image taken from page 189 of 'Through Unknown Tibet ... Illustrated'"},
#   {u'farm': 6,
#    u'id': u'11291779295',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'0b2533af9e',
#    u'server': u'5512',
#    u'title': u"Image taken from page 473 of 'Our Own Country. Canada, scenic and descriptive ... Illustrated, etc'"},
#   {u'farm': 6,
#    u'id': u'11290077493',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'2b11c1d3c5',
#    u'server': u'5541',
#    u'title': u"Image taken from page 4 of 'Alice's Puppy Dog. [Two poems.]'"},
#   {u'farm': 4,
#    u'id': u'11286269723',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'556b706e09',
#    u'server': u'3821',
#    u'title': u"Image taken from page 243 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 8,
#    u'id': u'11286026675',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'd61cc5fb00',
#    u'server': u'7455',
#    u'title': u"Image taken from page 344 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 4,
#    u'id': u'11285965896',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'8a05838db8',
#    u'server': u'3742',
#    u'title': u"Image taken from page 13 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 6,
#    u'id': u'11285849615',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'9d86c2a4a9',
#    u'server': u'5514',
#    u'title': u"Image taken from page 185 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 8,
#    u'id': u'11285878653',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'42de07bd88',
#    u'server': u'7410',
#    u'title': u"Image taken from page 136 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 6,
#    u'id': u'11285695214',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'd3a47dd42c',
#    u'server': u'5492',
#    u'title': u"Image taken from page 35 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 3,
#    u'id': u'11285612254',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'1cc820e95b',
#    u'server': u'2836',
#    u'title': u"Image taken from page 233 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 6,
#    u'id': u'11285469613',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'0efc37f7dd',
#    u'server': u'5480',
#    u'title': u"Image taken from page 43 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 8,
#    u'id': u'11285335503',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'd7f4e3d1b4',
#    u'server': u'7350',
#    u'title': u"Image taken from page 288 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 3,
#    u'id': u'11285424033',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'2cf5d0cb44',
#    u'server': u'2819',
#    u'title': u"Image taken from page 151 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 4,
#    u'id': u'11285014313',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'df8b402834',
#    u'server': u'3826',
#    u'title': u"Image taken from page 226 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"},
#   {u'farm': 3,
#    u'id': u'11284889593',
#    u'isfamily': 0,
#    u'isfriend': 0,
#    u'ispublic': 1,
#    u'owner': u'12403504@N02',
#    u'secret': u'643420a9cf',
#    u'server': u'2846',
#    u'title': u"Image taken from page 158 of 'Aileen Aroon: a memoir [of a dog]. With other tales of faithful friends and favourites, sketched from the life'"}],
#  u'total': u'2071'}

# %%
photos = get_photos_static_urls(flickr.photos_search(
        tag_mode='any',
        tags='dog, puppy',
        license='7',
        format='json'))

HTML(template.render(items=photos[:20]))
# Out:
# <style>
#   .wrap img {
#     margin-left: 0px;
#     margin-right: 0px;
#     display: inline-block;
#     width: 150px;
#   }
#
# .wrap {
#    /* Prevent vertical gaps */
#    line-height: 0;
#
#    -webkit-column-count: 5;
#    -webkit-column-gap:   0px;
#    -moz-column-count:    5;
#    -moz-column-gap:      0px;
#    column-count:         5;
#    column-gap:           0px;
#
# }
# .wrap img {
#   /* Just in case there are inline attributes */
#   width: 100% !important;
#   height: auto !important;
# }
#
# </style>
#
# <div class="wrap">
#  <img src="http://farm6.staticflickr.com/5538/11292885426_f09443f484_m.jpg"/><img src="http://farm8.staticflickr.com/7373/11222803106_0963978e49_m.jpg"/><img src="http://farm6.staticflickr.com/5483/11062816216_7f41ab7c0e_m.jpg"/><img src="http://farm6.staticflickr.com/5495/11007099313_32784f940a_m.jpg"/><img src="http://farm6.staticflickr.com/5473/12662111824_f9c9fa8a68_m.jpg"/><img src="http://farm6.staticflickr.com/5472/12609397644_f232710c3e_m.jpg"/><img src="http://farm8.staticflickr.com/7315/12584715825_78733cd4b1_m.jpg"/><img src="http://farm4.staticflickr.com/3764/12525423004_f8233d4be7_m.jpg"/><img src="http://farm8.staticflickr.com/7302/12513169314_c52b1c029f_m.jpg"/><img src="http://farm8.staticflickr.com/7345/12459205903_be49135916_m.jpg"/><img src="http://farm4.staticflickr.com/3737/12218739974_2d48d2ea4d_m.jpg"/><img src="http://farm4.staticflickr.com/3810/12115019935_66e0892107_m.jpg"/><img src="http://farm8.staticflickr.com/7313/11987368804_fce65e4cc0_m.jpg"/><img src="http://farm4.staticflickr.com/3748/11733331783_0434eaec39_m.jpg"/><img src="http://farm4.staticflickr.com/3726/11254275105_115b3cbaeb_m.jpg"/><img src="http://farm4.staticflickr.com/3759/11432700246_c6a606d770_m.jpg"/><img src="http://farm3.staticflickr.com/2851/11403109745_038200bd7b_m.jpg"/><img src="http://farm6.staticflickr.com/5474/11307072035_24ee044e37_m.jpg"/><img src="http://farm6.staticflickr.com/5492/11307096366_2911dbd2ff_m.jpg"/><img src="http://farm3.staticflickr.com/2878/11306044406_7c4a61b741_m.jpg"/>
# </div>
