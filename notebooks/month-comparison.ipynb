# %%
"""
When is the most popular time (e.g. month of the year) to upload photos of pets?
"""

# %%
from main import *

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series, Index
import pandas as pd

from itertools import islice

# %%
# Photos with the text "dog" taken in 2013

query = flickr.photos_search(
            text='dog',
            min_taken_date='2013-01-01',
            max_taken_date='2013-12-31',
            extras='date_upload, date_taken',
            license="7",
            format='json')

photos = get_photos(query)
photos
# Out:
# [{u'datetaken': u'2013-12-09 17:13:02',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397812050',
#   u'farm': 6,
#   u'id': u'11292885426',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'owner': u'12403504@N02',
#   u'secret': u'f09443f484',
#   u'server': u'5538',
#   u'title': u"Image taken from page 392 of 'Northward over the \u201cGreat Ice\u201d: a narrative of life and work along the shores and upon the interior ice-cap of Northern Greenland in the years 1886 and 1891-1897 ... With maps, diagrams, and about eight hundred illustrations'"},
#  {u'datetaken': u'2013-12-06 17:26:34',
#   u'datetakengranularity': u'0',
#   u'dateupload': u'1397207324',
#   u'farm': 4,
#   u'id': u'11239342056',
#   u'isfamily': 0,
#   u'isfriend': 0,
#   u'ispublic': 1,
#   u'owner': u'12403504@N02',
#   u'secret': u'0f6756fee1',
#   u'server': u'3719',
# ...

# %%
len(photos)
# Out:
# 100

# %%
get_count(query)
# Out:
# u'349'

# %%
dogs2013 = DataFrame(photos)
dogs2013.head(10)
# Out:
#              datetaken datetakengranularity  dateupload  farm           id  \
# 0  2013-12-09 17:13:02                    0  1397812050     6  11292885426
# 1  2013-12-06 17:26:34                    0  1397207324     4  11239342056
# 2  2013-12-05 15:46:33                    0  1395392517     8  11222803106
# 3  2013-11-26 06:42:51                    0  1395392858     6  11062816216
# 4  2013-11-23 09:48:20                    0  1393578405     6  11007099313
# 5  2013-12-05 15:53:06                    0  1393577966     6  11222889566
# 6  2013-03-14 16:14:36                    0  1392850286     6  12644208044
# 7  2013-11-22 11:53:37                    0  1389993512     4  12001524353
# 8  2013-11-22 11:48:16                    0  1389993511     6  12001586914
# 9  2013-11-22 11:42:57                    0  1389993510     8  12002040576
#
#    isfamily  isfriend  ispublic         owner      secret server  \
# 0         0         0         1  12403504@N02  f09443f484   5538
# ...

# %%
# Jan 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-01-01',
        max_taken_date='2013-01-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'3'

# %%
# Feb 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-02-01',
        max_taken_date='2013-02-29',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'11'

# %%
# Mar 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-03-01',
        max_taken_date='2013-03-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'6'

# %%
# April 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-04-01',
        max_taken_date='2013-04-30',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'5'

# %%
# May 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-05-01',
        max_taken_date='2013-05-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'1'

# %%
# June 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-06-01',
        max_taken_date='2013-06-30',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'8'

# %%
# July 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-07-01',
        max_taken_date='2013-07-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'3'

# %%
# Aug 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-08-01',
        max_taken_date='2013-08-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'3'

# %%
# Sep 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-09-01',
        max_taken_date='2013-09-30',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'12'

# %%
# Oct 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-10-01',
        max_taken_date='2013-10-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'6'

# %%
# Nov 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-11-01',
        max_taken_date='2013-11-30',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'174'

# %%
# Dec 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-12-01',
        max_taken_date='2013-12-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'92'

# %%
# Jan 2014
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2014-01-01',
        max_taken_date='2014-01-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'3'

# %%
# Feb 2014
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2014-01-01',
        max_taken_date='2014-01-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))

# %%
# Nov 2012
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2012-11-01',
        max_taken_date='2012-11-30',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
# Out:
# u'0'

# %%
# Dec 2013
get_count(flickr.photos_search(
        text='dog',
        min_taken_date='2013-12-01',
        max_taken_date='2013-12-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))

# %%
photos = get_photos_static_urls(flickr.photos_search(
        text='dog',
        min_taken_date='2013-01-01',
        max_taken_date='2013-01-31',
        extras='date_upload, date_taken',
        license="7",
        format='json'))
HTML(template.render(items=photos[:20]))
# Out:
# <style>
#   .wrap img {
#     margin-left: 0px;
#     margin-right: 0px;
#     display: inline-block;
#     width: 150px;
#   }
#
# .wrap {
#    /* Prevent vertical gaps */
#    line-height: 0;
#
#    -webkit-column-count: 5;
#    -webkit-column-gap:   0px;
#    -moz-column-count:    5;
#    -moz-column-gap:      0px;
#    column-count:         5;
#    column-gap:           0px;
#
# }
# .wrap img {
#   /* Just in case there are inline attributes */
#   width: 100% !important;
#   height: auto !important;
# }
#
# </style>
#
# <div class="wrap">
#  <img src="http://farm4.staticflickr.com/3715/11711236916_4215b6c548_m.jpg"/><img src="http://farm9.staticflickr.com/8330/8393281496_a293625fa8_m.jpg"/><img src="http://farm9.staticflickr.com/8471/8356362331_beeceaf5e4_m.jpg"/>
# </div>
